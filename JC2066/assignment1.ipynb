# %% [markdown]
# Student Name: Wang minda
#
# Student ID: 58521778

# %% [markdown]
# # JC2066 Assignment 1: College Admissions Algorithms
#
# ### Learning objectives:
# - Explore algorithmic decision-making and representations of people in data
# - Understanding outliers, missing information in data, and human judgments in algorithmic decisions
#
# ### About Submission
# The questions include two parts: **coding** (Q1 to Q5) and **reflection** (Q6 & Q7). After completing all questions, **only upload the finished iPython Notebook file (.ipynb) to Canvas**. Remember to check that you have submitted the file correctly on Canvas (You do not need to submit the files (e.g., csv) you output through your code). **Make sure all cells in your file run without errors after restarting the kernel**.
#
# The deadline to submit your files to Canvas is **Mar. 23rd (Sunday), 11:59 pm**. Please note that this assignment accounts for `20% of your final course score`.
#
# ### Background
# As you know, the college admissions process involves a lot of types of data from prospective students to make decisions. With the number of applicants increasing, colleges may begin relying on algorithms to select which applications should receive more intensive human review. An algorithm could use quantitative data--such as GPA and SAT score--to provide initial recommendations. In fact, there is more data available than ever. Many colleges even track data about prospective student engagement
#
# > e.g., whether they open emails, visit the college website, engage on social media, etc. This creates a “demonstrated interest” value.
#
# [Based on a survey of college admissions officers](https://www.insidehighered.com/admissions/article/2018/11/12/new-data-admissions-including-application-trends-early-decision-and), we know some of the weights that humans tend to give to these different types of data. Your task will be to create a program that iterates through a list of data points and provides a recommendation for which prospective students are likely to be the best candidates for admission.
#
# Prospective student data is organized in the **admission_algorithms_dataset.csv** file such that the data for each student is on one line, with the values separated by commas. Examples of student data might be:
#
# > Student, SAT, GPA, Interest, High School Quality, Semester 1, Semester 2, Semester 3, Semester 4
# >
# > Abbess Horror , 1300, 3.61, 10, 7, 95, 86, 91, 94
# >
# > Adele Hawthorne , 1400, 3.67, 0, 9, 97, 83, 85, 86
# >
# > Adelicia von Krupp , 900, 4, 5, 2, 88, 92, 83, 72
#
# The data includes these columns (in order):
#
# - **Student**: a unique identifier for each student (their name)
# - **SAT score**: value between 0 and 1600
# - **GPA**: value between 0 and 5
# - **Interest**: value between 0 and 10 (from very low interest to very high interest)
# - **High School Quality**: value between 0 and 10 (from very low-quality to very high-quality high school)
# - **Semester 1**: average grade for semester 1
# - **Semester 2**: average grade for semester 2
# - **Semester 3**: average grade for semester 3
# - **Semester 4**: average grade for semester 4

# %% [markdown]
# ## **PART 1 CODING TASKS**
#
# ### **Question 1 - Getting set up with our data (15 points)**
#
# First, we need to make sure that we can appropriately read in the data line by line, parsing/converting each line into a list and converting each element in the list to the appropriate type.
#
# ### Task 1
# Read in your data set and loop through its contents line by line. Make use of the `str.split(delimiter)` function to break each individual line into a list of elements (Name, SAT, GPA, etc.). Ensure that you've done this correctly by printing your list after using the split() function. You'll want to delete this print statement later, but make sure to double check that you are correctly looping over all the lines before moving on! Once you have each line in a list, save the student's name in a variable, then delete this element from your list.

# %%
filename = "admission_algorithms_dataset.csv"

input_file = open(filename, "r")

# grab the line with the headers
headers = input_file.readline()

### INSERT YOUR CODE HERE
student_names = []
all_data = []

for line in input_file:
    data = line.strip().split(",")  

    student_name = data.pop(0) 
    student_names.append(student_name)  
    all_data.append(data)  

input_file.close()

# %% [markdown]
# ### Task 2
# Once you have a list of strings for each line, you will write a function `convert_row_type()` that takes one list of elements (representing the data for one student) as a parameter and converts it so that all numbers (currently represented as strings) are converted to floats. Make sure not to lose any information when you do this conversion! Implement this as a pure list function. , i.e., return a new list and do not modify the list passed in.
#
# Example:
# > Input: ["1300", "3.61", "10" ,"7" ,"95" ,"86" ,"91" ,"94"]
# >
# > Return value: [1300.0, 3.61, 10.0, 7.0, 95.0, 86.0, 91.0, 94.0]
#
# A function `check_row_types()` is provided for you to check your results. Once you've called `convert_row_type()` on the list representing one row, you may call this function to ensure that you have correctly converted all elements to floats.

# %%
# Provided code
# This function checks to ensure that a list is of length
# 8 and that each element is type float
# Parameters:
# row - a list to check
# Returns True if the length of row is 8 and all elements are floats
def check_row_types(row):
    if len(row) != 8:
        print("Length incorrect! (should be 8): " + str(row))
        return False
    ind = 0
    while ind < len(row):
        if type(row[ind]) != float:
            print("Type of element incorrect: " + str(row[ind]) + " which is " + str(type(row[ind])))
            return False
        ind += 1
    return True

# %%
### INSERT YOUR CODE HERE
def convert_row_type(row):
    return [float(value) for value in row]  

all_converted_data = []

for i in range(len(all_data)): 
    original_data = all_data[i]  
    converted_row = convert_row_type(original_data)
    all_converted_data.append(converted_row) 

    print(original_data) 
    print(converted_row)  
    print(check_row_types(converted_row))
# Out:
# ['1300', '3.61', '10', '7', '95', '86', '91', '94']
# [1300.0, 3.61, 10.0, 7.0, 95.0, 86.0, 91.0, 94.0]
# True
# ['1400', '3.67', '0', '9', '97', '83', '85', '86']
# [1400.0, 3.67, 0.0, 9.0, 97.0, 83.0, 85.0, 86.0]
# True
# ['900', '4', '5', '2', '88', '92', '83', '72']
# [900.0, 4.0, 5.0, 2.0, 88.0, 92.0, 83.0, 72.0]
# True
# ['1360', '3.19', '0', '9', '90', '85', '97', '87']
# [1360.0, 3.19, 0.0, 9.0, 90.0, 85.0, 97.0, 87.0]
# True
# ['1180', '2.93', '2', '7', '93', '81', '90', '87']
# [1180.0, 2.93, 2.0, 7.0, 93.0, 81.0, 90.0, 87.0]
# True
# ['1180', '3', '6', '7', '95', '88', '97', '97']
# [1180.0, 3.0, 6.0, 7.0, 95.0, 88.0, 97.0, 97.0]
# True
# ['1140', '2.98', '10', '8', '92', '81', '95', '90']
# [1140.0, 2.98, 10.0, 8.0, 92.0, 81.0, 95.0, 90.0]
# True
# ['1190', '3.08', '1', '7', '96', '82', '83', '81']
# [1190.0, 3.08, 1.0, 7.0, 96.0, 82.0, 83.0, 81.0]
# True
# ['1400', '3.39', '10', '9', '85', '87', '92', '98']
# [1400.0, 3.39, 10.0, 9.0, 85.0, 87.0, 92.0, 98.0]
# True
# ['1310', '3.92', '8', '4', '95', '88', '87', '95']
# [1310.0, 3.92, 8.0, 4.0, 95.0, 88.0, 87.0, 95.0]
# True
# ['1310', '4', '1', '1', '90', '86', '81', '82']
# [1310.0, 4.0, 1.0, 1.0, 90.0, 86.0, 81.0, 82.0]
# True
# ['1100', '3.22', '10', '3', '93', '89', '94', '96']
# [1100.0, 3.22, 10.0, 3.0, 93.0, 89.0, 94.0, 96.0]
# True
# ['1150', '4.6', '9', '2', '86', '90', '83', '89']
# [1150.0, 4.6, 9.0, 2.0, 86.0, 90.0, 83.0, 89.0]
# True
# ['1220', '3.08', '7', '10', '96', '92', '81', '84']
# [1220.0, 3.08, 7.0, 10.0, 96.0, 92.0, 81.0, 84.0]
# True
# ['1340', '4', '2', '4', '90', '89', '95', '92']
# [1340.0, 4.0, 2.0, 4.0, 90.0, 89.0, 95.0, 92.0]
# True
# ['1400', '3.44', '10', '2', '88', '92', '85', '67']
# [1400.0, 3.44, 10.0, 2.0, 88.0, 92.0, 85.0, 67.0]
# True
# ['1000', '4.2', '3', '3', '86', '85', '86', '79']
# [1000.0, 4.2, 3.0, 3.0, 86.0, 85.0, 86.0, 79.0]
# True
# ['950', '2.56', '5', '7', '97', '88', '95', '89']
# [950.0, 2.56, 5.0, 7.0, 97.0, 88.0, 95.0, 89.0]
# True
# ['1420', '3.75', '10', '1', '88', '83', '87', '94']
# [1420.0, 3.75, 10.0, 1.0, 88.0, 83.0, 87.0, 94.0]
# True
# ['1350', '3.81', '7', '7', '92', '86', '81', '83']
# [1350.0, 3.81, 7.0, 7.0, 92.0, 86.0, 81.0, 83.0]
# True
# ['1160', '3.17', '0', '4', '87', '87', '81', '93']
# [1160.0, 3.17, 0.0, 4.0, 87.0, 87.0, 81.0, 93.0]
# True
# ['1190', '3.63', '3', '3', '90', '91', '83', '89']
# [1190.0, 3.63, 3.0, 3.0, 90.0, 91.0, 83.0, 89.0]
# True
# ['950', '2.82', '7', '3', '88', '90', '90', '82']
# [950.0, 2.82, 7.0, 3.0, 88.0, 90.0, 90.0, 82.0]
# True
# ['1200', '4.8', '0', '1', '90', '82', '90', '93']
# [1200.0, 4.8, 0.0, 1.0, 90.0, 82.0, 90.0, 93.0]
# True
# ['1250', '3.35', '2', '9', '97', '89', '97', '89']
# [1250.0, 3.35, 2.0, 9.0, 97.0, 89.0, 97.0, 89.0]
# True
# ['1420', '4.2', '3', '2', '97', '87', '95', '98']
# [1420.0, 4.2, 3.0, 2.0, 97.0, 87.0, 95.0, 98.0]
# True
# ['1380', '3.61', '0', '7', '96', '90', '88', '94']
# [1380.0, 3.61, 0.0, 7.0, 96.0, 90.0, 88.0, 94.0]
# True
# ['1500', '3.74', '0', '0', '92', '86', '81', '90']
# [1500.0, 3.74, 0.0, 0.0, 92.0, 86.0, 81.0, 90.0]
# True
# ['1240', '3.22', '3', '10', '97', '90', '82', '98']
# [1240.0, 3.22, 3.0, 10.0, 97.0, 90.0, 82.0, 98.0]
# True
# ['1090', '3.29', '5', '8', '95', '82', '97', '76']
# [1090.0, 3.29, 5.0, 8.0, 95.0, 82.0, 97.0, 76.0]
# True
# ['1530', '3.78', '7', '4', '95', '85', '89', '94']
# [1530.0, 3.78, 7.0, 4.0, 95.0, 85.0, 89.0, 94.0]
# True
# ['1310', '3.35', '7', '9', '89', '87', '83', '55']
# [1310.0, 3.35, 7.0, 9.0, 89.0, 87.0, 83.0, 55.0]
# True
# ['1180', '3.4', '9', '9', '93', '84', '90', '96']
# [1180.0, 3.4, 9.0, 9.0, 93.0, 84.0, 90.0, 96.0]
# True
# ['1520', '4.35', '5', '3', '94', '85', '84', '81']
# [1520.0, 4.35, 5.0, 3.0, 94.0, 85.0, 84.0, 81.0]
# True
# ['1200', '4.9', '10', '1', '87', '89', '97', '85']
# [1200.0, 4.9, 10.0, 1.0, 87.0, 89.0, 97.0, 85.0]
# True
# ['1190', '3.05', '8', '7', '94', '91', '98', '93']
# [1190.0, 3.05, 8.0, 7.0, 94.0, 91.0, 98.0, 93.0]
# True
# ['1240', '3.25', '2', '2', '86', '83', '90', '92']
# [1240.0, 3.25, 2.0, 2.0, 86.0, 83.0, 90.0, 92.0]
# True
# ['1260', '2.9', '0', '0', '94', '85', '82', '89']
# [1260.0, 2.9, 0.0, 0.0, 94.0, 85.0, 82.0, 89.0]
# True
# ['1180', '3.13', '8', '6', '86', '83', '97', '82']
# [1180.0, 3.13, 8.0, 6.0, 86.0, 83.0, 97.0, 82.0]
# True
# ['1200', '2.68', '9', '1', '90', '88', '86', '80']
# [1200.0, 2.68, 9.0, 1.0, 90.0, 88.0, 86.0, 80.0]
# True
# ['1050', '2.42', '5', '4', '93', '90', '92', '98']
# [1050.0, 2.42, 5.0, 4.0, 93.0, 90.0, 92.0, 98.0]
# True
# ['1330', '3.32', '8', '8', '97', '87', '97', '87']
# [1330.0, 3.32, 8.0, 8.0, 97.0, 87.0, 97.0, 87.0]
# True
# ['1210', '3.15', '0', '9', '91', '91', '85', '96']
# [1210.0, 3.15, 0.0, 9.0, 91.0, 91.0, 85.0, 96.0]
# True
# ['1280', '3.31', '10', '3', '92', '91', '87', '80']
# [1280.0, 3.31, 10.0, 3.0, 92.0, 91.0, 87.0, 80.0]
# True
# ['1260', '2.94', '1', '9', '91', '92', '96', '96']
# [1260.0, 2.94, 1.0, 9.0, 91.0, 92.0, 96.0, 96.0]
# True
# ['1140', '3.45', '1', '10', '85', '87', '95', '94']
# [1140.0, 3.45, 1.0, 10.0, 85.0, 87.0, 95.0, 94.0]
# True
# ['1250', '3.46', '4', '3', '86', '88', '85', '77']
# [1250.0, 3.46, 4.0, 3.0, 86.0, 88.0, 85.0, 77.0]
# True
# ['1160', '2.97', '10', '9', '88', '82', '95', '83']
# [1160.0, 2.97, 10.0, 9.0, 88.0, 82.0, 95.0, 83.0]
# True
# ['1140', '2.48', '8', '5', '94', '81', '89', '82']
# [1140.0, 2.48, 8.0, 5.0, 94.0, 81.0, 89.0, 82.0]
# True
# ['1290', '3.35', '0', '0', '91', '82', '82', '77']
# [1290.0, 3.35, 0.0, 0.0, 91.0, 82.0, 82.0, 77.0]
# True
# ['1360', '3.86', '8', '3', '96', '82', '97', '79']
# [1360.0, 3.86, 8.0, 3.0, 96.0, 82.0, 97.0, 79.0]
# True
# ['1080', '3.13', '10', '5', '85', '86', '96', '90']
# [1080.0, 3.13, 10.0, 5.0, 85.0, 86.0, 96.0, 90.0]
# True
# ['1370', '3.37', '5', '4', '88', '87', '83', '87']
# [1370.0, 3.37, 5.0, 4.0, 88.0, 87.0, 83.0, 87.0]
# True
# ['1170', '3.27', '4', '10', '89', '92', '97', '87']
# [1170.0, 3.27, 4.0, 10.0, 89.0, 92.0, 97.0, 87.0]
# True
# ['1260', '3.34', '4', '0', '98', '85', '89', '82']
# [1260.0, 3.34, 4.0, 0.0, 98.0, 85.0, 89.0, 82.0]
# True
# ['1370', '4', '3', '7', '86', '85', '97', '81']
# [1370.0, 4.0, 3.0, 7.0, 86.0, 85.0, 97.0, 81.0]
# True
# ['1250', '3.19', '0', '10', '91', '84', '92', '93']
# [1250.0, 3.19, 0.0, 10.0, 91.0, 84.0, 92.0, 93.0]
# True
# ['1090', '2.94', '5', '5', '97', '83', '87', '82']
# [1090.0, 2.94, 5.0, 5.0, 97.0, 83.0, 87.0, 82.0]
# True
# ['1380', '3.65', '5', '3', '93', '82', '93', '61']
# [1380.0, 3.65, 5.0, 3.0, 93.0, 82.0, 93.0, 61.0]
# True
# ['1150', '2.82', '6', '0', '97', '85', '84', '92']
# [1150.0, 2.82, 6.0, 0.0, 97.0, 85.0, 84.0, 92.0]
# True
# ['1210', '3.18', '9', '1', '86', '91', '90', '80']
# [1210.0, 3.18, 9.0, 1.0, 86.0, 91.0, 90.0, 80.0]
# True
# ['1100', '3.32', '8', '6', '94', '89', '98', '85']
# [1100.0, 3.32, 8.0, 6.0, 94.0, 89.0, 98.0, 85.0]
# True
# ['950', '4.1', '0', '2', '85', '86', '97', '81']
# [950.0, 4.1, 0.0, 2.0, 85.0, 86.0, 97.0, 81.0]
# True
# ['1560', '3.85', '10', '8', '94', '86', '87', '89']
# [1560.0, 3.85, 10.0, 8.0, 94.0, 86.0, 87.0, 89.0]
# True
# ['1430', '4', '1', '2', '94', '85', '98', '92']
# [1430.0, 4.0, 1.0, 2.0, 94.0, 85.0, 98.0, 92.0]
# True
# ['1420', '3.59', '5', '1', '85', '92', '81', '94']
# [1420.0, 3.59, 5.0, 1.0, 85.0, 92.0, 81.0, 94.0]
# True
# ['1330', '3.62', '3', '9', '97', '86', '93', '90']
# [1330.0, 3.62, 3.0, 9.0, 97.0, 86.0, 93.0, 90.0]
# True
# ['1170', '3.3', '6', '2', '97', '86', '82', '56']
# [1170.0, 3.3, 6.0, 2.0, 97.0, 86.0, 82.0, 56.0]
# True
# ['1460', '3.69', '9', '10', '92', '83', '88', '92']
# [1460.0, 3.69, 9.0, 10.0, 92.0, 83.0, 88.0, 92.0]
# True
# ['1310', '3.73', '3', '5', '86', '86', '94', '77']
# [1310.0, 3.73, 3.0, 5.0, 86.0, 86.0, 94.0, 77.0]
# True
# ['1320', '4', '7', '6', '94', '92', '89', '75']
# [1320.0, 4.0, 7.0, 6.0, 94.0, 92.0, 89.0, 75.0]
# True
# ['1130', '2.92', '3', '1', '97', '86', '95', '91']
# [1130.0, 2.92, 3.0, 1.0, 97.0, 86.0, 95.0, 91.0]
# True
# ['1180', '3.39', '8', '0', '95', '84', '91', '88']
# [1180.0, 3.39, 8.0, 0.0, 95.0, 84.0, 91.0, 88.0]
# True
# ['1490', '4', '10', '6', '97', '90', '89', '85']
# [1490.0, 4.0, 10.0, 6.0, 97.0, 90.0, 89.0, 85.0]
# True
# ['1290', '3.45', '8', '9', '98', '83', '86', '80']
# [1290.0, 3.45, 8.0, 9.0, 98.0, 83.0, 86.0, 80.0]
# True
# ['1340', '4', '10', '4', '98', '88', '88', '85']
# [1340.0, 4.0, 10.0, 4.0, 98.0, 88.0, 88.0, 85.0]
# True
# ['1290', '3.36', '9', '8', '87', '84', '97', '81']
# [1290.0, 3.36, 9.0, 8.0, 87.0, 84.0, 97.0, 81.0]
# True
# ['1350', '4', '3', '8', '93', '83', '85', '96']
# [1350.0, 4.0, 3.0, 8.0, 93.0, 83.0, 85.0, 96.0]
# True
# ['1100', '3.12', '9', '10', '93', '82', '95', '86']
# [1100.0, 3.12, 9.0, 10.0, 93.0, 82.0, 95.0, 86.0]
# True
# ['1410', '4', '7', '10', '85', '90', '91', '79']
# [1410.0, 4.0, 7.0, 10.0, 85.0, 90.0, 91.0, 79.0]
# True
# ['1140', '2.9', '5', '7', '93', '83', '86', '92']
# [1140.0, 2.9, 5.0, 7.0, 93.0, 83.0, 86.0, 92.0]
# True
# ['1160', '3.07', '4', '6', '87', '82', '92', '75']
# [1160.0, 3.07, 4.0, 6.0, 87.0, 82.0, 92.0, 75.0]
# True
# ['1080', '2.71', '3', '1', '96', '82', '96', '50']
# [1080.0, 2.71, 3.0, 1.0, 96.0, 82.0, 96.0, 50.0]
# True
# ['1090', '2.91', '3', '4', '92', '88', '84', '78']
# [1090.0, 2.91, 3.0, 4.0, 92.0, 88.0, 84.0, 78.0]
# True
# ['1150', '4.7', '2', '3', '91', '85', '94', '93']
# [1150.0, 4.7, 2.0, 3.0, 91.0, 85.0, 94.0, 93.0]
# True
# ['1090', '2.98', '6', '10', '96', '84', '90', '81']
# [1090.0, 2.98, 6.0, 10.0, 96.0, 84.0, 90.0, 81.0]
# True
# ['1370', '4.1', '6', '8', '87', '91', '94', '77']
# [1370.0, 4.1, 6.0, 8.0, 87.0, 91.0, 94.0, 77.0]
# True
# ['1330', '3.48', '1', '2', '87', '87', '88', '96']
# [1330.0, 3.48, 1.0, 2.0, 87.0, 87.0, 88.0, 96.0]
# True
# ['1370', '3.28', '0', '7', '95', '91', '90', '80']
# [1370.0, 3.28, 0.0, 7.0, 95.0, 91.0, 90.0, 80.0]
# True
# ['1520', '4', '0', '10', '86', '87', '86', '88']
# [1520.0, 4.0, 0.0, 10.0, 86.0, 87.0, 86.0, 88.0]
# True
# ['1520', '3.83', '10', '0', '91', '83', '90', '75']
# [1520.0, 3.83, 10.0, 0.0, 91.0, 83.0, 90.0, 75.0]
# True
# ['1220', '3.64', '7', '6', '92', '83', '81', '98']
# [1220.0, 3.64, 7.0, 6.0, 92.0, 83.0, 81.0, 98.0]
# True
# ['1550', '3.9', '6', '3', '98', '81', '82', '97']
# [1550.0, 3.9, 6.0, 3.0, 98.0, 81.0, 82.0, 97.0]
# True
# ['1170', '2.93', '8', '0', '86', '86', '88', '79']
# [1170.0, 2.93, 8.0, 0.0, 86.0, 86.0, 88.0, 79.0]
# True
# ['1280', '3.44', '5', '3', '94', '90', '85', '84']
# [1280.0, 3.44, 5.0, 3.0, 94.0, 90.0, 85.0, 84.0]
# True
# ['1110', '3.33', '2', '6', '90', '86', '93', '98']
# [1110.0, 3.33, 2.0, 6.0, 90.0, 86.0, 93.0, 98.0]
# True
# ['1180', '3.52', '5', '9', '91', '92', '96', '95']
# [1180.0, 3.52, 5.0, 9.0, 91.0, 92.0, 96.0, 95.0]
# True
# ['1240', '3.57', '6', '9', '89', '92', '82', '81']
# [1240.0, 3.57, 6.0, 9.0, 89.0, 92.0, 82.0, 81.0]
# True
# ['1120', '2.88', '0', '5', '96', '82', '84', '58']
# [1120.0, 2.88, 0.0, 5.0, 96.0, 82.0, 84.0, 58.0]
# True
# ['1140', '3.31', '4', '0', '91', '87', '82', '90']
# [1140.0, 3.31, 4.0, 0.0, 91.0, 87.0, 82.0, 90.0]
# True
# ['1310', '3.15', '10', '10', '97', '86', '97', '77']
# [1310.0, 3.15, 10.0, 10.0, 97.0, 86.0, 97.0, 77.0]
# True
# ['1400', '3.57', '7', '2', '95', '81', '95', '95']
# [1400.0, 3.57, 7.0, 2.0, 95.0, 81.0, 95.0, 95.0]
# True
# ['1290', '3.33', '0', '4', '98', '84', '94', '84']
# [1290.0, 3.33, 0.0, 4.0, 98.0, 84.0, 94.0, 84.0]
# True
# ['1150', '4.7', '6', '4', '96', '90', '82', '87']
# [1150.0, 4.7, 6.0, 4.0, 96.0, 90.0, 82.0, 87.0]
# True
# ['1450', '3.95', '6', '7', '95', '81', '94', '86']
# [1450.0, 3.95, 6.0, 7.0, 95.0, 81.0, 94.0, 86.0]
# True
# ['1000', '2.97', '8', '10', '86', '88', '90', '86']
# [1000.0, 2.97, 8.0, 10.0, 86.0, 88.0, 90.0, 86.0]
# True
# ['1310', '3.56', '4', '0', '90', '87', '98', '90']
# [1310.0, 3.56, 4.0, 0.0, 90.0, 87.0, 98.0, 90.0]
# True
# ['1170', '3.13', '7', '4', '92', '89', '94', '77']
# [1170.0, 3.13, 7.0, 4.0, 92.0, 89.0, 94.0, 77.0]
# True
# ['1180', '2.93', '5', '9', '85', '92', '93', '83']
# [1180.0, 2.93, 5.0, 9.0, 85.0, 92.0, 93.0, 83.0]
# True
# ['1370', '3.45', '10', '8', '94', '83', '91', '84']
# [1370.0, 3.45, 10.0, 8.0, 94.0, 83.0, 91.0, 84.0]
# True
# ['1160', '3.08', '0', '6', '91', '86', '82', '93']
# [1160.0, 3.08, 0.0, 6.0, 91.0, 86.0, 82.0, 93.0]
# True
# ['1140', '3.41', '3', '10', '86', '87', '98', '90']
# [1140.0, 3.41, 3.0, 10.0, 86.0, 87.0, 98.0, 90.0]
# True
# ['1190', '3', '6', '3', '93', '86', '88', '98']
# [1190.0, 3.0, 6.0, 3.0, 93.0, 86.0, 88.0, 98.0]
# True
# ['1310', '3.22', '0', '5', '85', '81', '89', '90']
# [1310.0, 3.22, 0.0, 5.0, 85.0, 81.0, 89.0, 90.0]
# True
# ['1300', '3.84', '3', '4', '87', '89', '92', '78']
# [1300.0, 3.84, 3.0, 4.0, 87.0, 89.0, 92.0, 78.0]
# True
# ['1490', '3.99', '1', '5', '94', '84', '84', '90']
# [1490.0, 3.99, 1.0, 5.0, 94.0, 84.0, 84.0, 90.0]
# True
# ['1250', '3.45', '3', '10', '93', '81', '88', '90']
# [1250.0, 3.45, 3.0, 10.0, 93.0, 81.0, 88.0, 90.0]
# True
# ['1460', '3.72', '8', '6', '87', '83', '94', '96']
# [1460.0, 3.72, 8.0, 6.0, 87.0, 83.0, 94.0, 96.0]
# True
# ['1510', '3.7', '3', '0', '88', '86', '82', '84']
# [1510.0, 3.7, 3.0, 0.0, 88.0, 86.0, 82.0, 84.0]
# True
# ['1060', '2.92', '0', '9', '91', '89', '87', '96']
# [1060.0, 2.92, 0.0, 9.0, 91.0, 89.0, 87.0, 96.0]
# True
# ['1410', '3.74', '8', '6', '98', '92', '84', '86']
# [1410.0, 3.74, 8.0, 6.0, 98.0, 92.0, 84.0, 86.0]
# True
# ['1160', '2.67', '2', '5', '91', '89', '82', '81']
# [1160.0, 2.67, 2.0, 5.0, 91.0, 89.0, 82.0, 81.0]
# True
# ['1050', '2.85', '6', '4', '87', '91', '90', '85']
# [1050.0, 2.85, 6.0, 4.0, 87.0, 91.0, 90.0, 85.0]
# True
# ['1010', '4.25', '6', '4', '93', '86', '93', '65']
# [1010.0, 4.25, 6.0, 4.0, 93.0, 86.0, 93.0, 65.0]
# True
# ['1470', '3.88', '9', '4', '88', '84', '89', '96']
# [1470.0, 3.88, 9.0, 4.0, 88.0, 84.0, 89.0, 96.0]
# True
# ['1380', '3.38', '10', '4', '93', '88', '83', '84']
# [1380.0, 3.38, 10.0, 4.0, 93.0, 88.0, 83.0, 84.0]
# True
# ['1190', '3.54', '8', '1', '95', '85', '81', '88']
# [1190.0, 3.54, 8.0, 1.0, 95.0, 85.0, 81.0, 88.0]
# True
# ['1410', '3.74', '7', '0', '87', '86', '95', '75']
# [1410.0, 3.74, 7.0, 0.0, 87.0, 86.0, 95.0, 75.0]
# True
# ['1310', '3.19', '1', '9', '88', '91', '93', '98']
# [1310.0, 3.19, 1.0, 9.0, 88.0, 91.0, 93.0, 98.0]
# True
# ['1080', '3.15', '7', '4', '91', '86', '83', '82']
# [1080.0, 3.15, 7.0, 4.0, 91.0, 86.0, 83.0, 82.0]
# True
# ['1270', '3.17', '0', '1', '92', '83', '86', '91']
# [1270.0, 3.17, 0.0, 1.0, 92.0, 83.0, 86.0, 91.0]
# True
# ['1190', '2.79', '5', '7', '94', '82', '88', '82']
# [1190.0, 2.79, 5.0, 7.0, 94.0, 82.0, 88.0, 82.0]
# True
# ['1140', '3.4', '8', '7', '90', '90', '87', '76']
# [1140.0, 3.4, 8.0, 7.0, 90.0, 90.0, 87.0, 76.0]
# True
# ['1230', '3.08', '10', '0', '86', '92', '87', '82']
# [1230.0, 3.08, 10.0, 0.0, 86.0, 92.0, 87.0, 82.0]
# True
# ['1090', '2.95', '7', '3', '87', '86', '93', '75']
# [1090.0, 2.95, 7.0, 3.0, 87.0, 86.0, 93.0, 75.0]
# True
# ['1400', '3.57', '6', '4', '97', '92', '85', '94']
# [1400.0, 3.57, 6.0, 4.0, 97.0, 92.0, 85.0, 94.0]
# True
# ['1260', '3.33', '5', '2', '87', '90', '96', '75']
# [1260.0, 3.33, 5.0, 2.0, 87.0, 90.0, 96.0, 75.0]
# True
# ['1590', '4', '3', '2', '97', '91', '88', '78']
# [1590.0, 4.0, 3.0, 2.0, 97.0, 91.0, 88.0, 78.0]
# True
# ['1190', '3.4', '1', '9', '96', '86', '92', '88']
# [1190.0, 3.4, 1.0, 9.0, 96.0, 86.0, 92.0, 88.0]
# True
# ['1220', '3.58', '5', '9', '85', '92', '94', '94']
# [1220.0, 3.58, 5.0, 9.0, 85.0, 92.0, 94.0, 94.0]
# True
# ['1470', '3.93', '7', '8', '97', '88', '86', '83']
# [1470.0, 3.93, 7.0, 8.0, 97.0, 88.0, 86.0, 83.0]
# True
# ['1420', '3.52', '7', '1', '88', '82', '98', '75']
# [1420.0, 3.52, 7.0, 1.0, 88.0, 82.0, 98.0, 75.0]
# True
# ['1380', '3.94', '10', '0', '98', '91', '94', '90']
# [1380.0, 3.94, 10.0, 0.0, 98.0, 91.0, 94.0, 90.0]
# True
# ['1260', '3.4', '10', '2', '94', '81', '94', '97']
# [1260.0, 3.4, 10.0, 2.0, 94.0, 81.0, 94.0, 97.0]
# True
# ['1380', '3.4', '5', '3', '96', '82', '81', '89']
# [1380.0, 3.4, 5.0, 3.0, 96.0, 82.0, 81.0, 89.0]
# True
# ['1410', '3.43', '1', '10', '92', '82', '93', '87']
# [1410.0, 3.43, 1.0, 10.0, 92.0, 82.0, 93.0, 87.0]
# True
# ['1300', '3.4', '10', '5', '86', '86', '91', '92']
# [1300.0, 3.4, 10.0, 5.0, 86.0, 86.0, 91.0, 92.0]
# True
# ['940', '2.71', '9', '9', '97', '83', '97', '98']
# [940.0, 2.71, 9.0, 9.0, 97.0, 83.0, 97.0, 98.0]
# True
# ['1150', '2.91', '0', '5', '92', '86', '92', '83']
# [1150.0, 2.91, 0.0, 5.0, 92.0, 86.0, 92.0, 83.0]
# True
# ['1290', '3.31', '1', '8', '89', '84', '86', '86']
# [1290.0, 3.31, 1.0, 8.0, 89.0, 84.0, 86.0, 86.0]
# True
# ['1330', '3.74', '5', '10', '90', '91', '86', '78']
# [1330.0, 3.74, 5.0, 10.0, 90.0, 91.0, 86.0, 78.0]
# True
# ['1280', '3.38', '0', '4', '98', '81', '89', '76']
# [1280.0, 3.38, 0.0, 4.0, 98.0, 81.0, 89.0, 76.0]
# True
# ['1510', '3.94', '5', '1', '88', '84', '97', '82']
# [1510.0, 3.94, 5.0, 1.0, 88.0, 84.0, 97.0, 82.0]
# True
# ['1140', '3.46', '10', '0', '96', '83', '93', '86']
# [1140.0, 3.46, 10.0, 0.0, 96.0, 83.0, 93.0, 86.0]
# True
# ['1440', '3.69', '2', '5', '90', '91', '85', '78']
# [1440.0, 3.69, 2.0, 5.0, 90.0, 91.0, 85.0, 78.0]
# True
# ['980', '2.86', '0', '3', '97', '92', '96', '85']
# [980.0, 2.86, 0.0, 3.0, 97.0, 92.0, 96.0, 85.0]
# True
# ['930', '2.52', '7', '0', '88', '82', '81', '75']
# [930.0, 2.52, 7.0, 0.0, 88.0, 82.0, 81.0, 75.0]
# True
# ['1260', '3.58', '6', '4', '92', '83', '93', '89']
# [1260.0, 3.58, 6.0, 4.0, 92.0, 83.0, 93.0, 89.0]
# True
# ['1280', '3.49', '10', '2', '96', '81', '84', '84']
# [1280.0, 3.49, 10.0, 2.0, 96.0, 81.0, 84.0, 84.0]
# True
# ['1470', '3.82', '8', '5', '86', '82', '89', '90']
# [1470.0, 3.82, 8.0, 5.0, 86.0, 82.0, 89.0, 90.0]
# True
# ['1200', '3.13', '4', '8', '98', '82', '89', '91']
# [1200.0, 3.13, 4.0, 8.0, 98.0, 82.0, 89.0, 91.0]
# True
# ['1370', '3.5', '2', '2', '88', '88', '87', '76']
# [1370.0, 3.5, 2.0, 2.0, 88.0, 88.0, 87.0, 76.0]
# True
# ['1220', '3.56', '3', '10', '92', '91', '83', '89']
# [1220.0, 3.56, 3.0, 10.0, 92.0, 91.0, 83.0, 89.0]
# True
# ['1060', '2.73', '4', '4', '91', '85', '88', '79']
# [1060.0, 2.73, 4.0, 4.0, 91.0, 85.0, 88.0, 79.0]
# True
# ['1200', '4.9', '10', '1', '86', '92', '89', '79']
# [1200.0, 4.9, 10.0, 1.0, 86.0, 92.0, 89.0, 79.0]
# True
# ['1440', '4', '3', '10', '91', '91', '81', '83']
# [1440.0, 4.0, 3.0, 10.0, 91.0, 91.0, 81.0, 83.0]
# True
# ['1210', '3.24', '9', '5', '94', '82', '83', '94']
# [1210.0, 3.24, 9.0, 5.0, 94.0, 82.0, 83.0, 94.0]
# True
# ['1480', '3.77', '0', '10', '98', '91', '85', '86']
# [1480.0, 3.77, 0.0, 10.0, 98.0, 91.0, 85.0, 86.0]
# True
# ['1420', '4', '10', '8', '98', '91', '98', '76']
# [1420.0, 4.0, 10.0, 8.0, 98.0, 91.0, 98.0, 76.0]
# True
# ['1390', '3.62', '9', '5', '90', '92', '89', '94']
# [1390.0, 3.62, 9.0, 5.0, 90.0, 92.0, 89.0, 94.0]
# True
# ['1200', '3.51', '2', '9', '85', '86', '90', '89']
# [1200.0, 3.51, 2.0, 9.0, 85.0, 86.0, 90.0, 89.0]
# True
# ['1160', '2.81', '0', '1', '97', '86', '94', '96']
# [1160.0, 2.81, 0.0, 1.0, 97.0, 86.0, 94.0, 96.0]
# True
# ['1380', '3.48', '9', '10', '90', '83', '81', '84']
# [1380.0, 3.48, 9.0, 10.0, 90.0, 83.0, 81.0, 84.0]
# True
# ['1320', '3.43', '0', '6', '95', '86', '83', '88']
# [1320.0, 3.43, 0.0, 6.0, 95.0, 86.0, 83.0, 88.0]
# True
# ['1220', '3.53', '5', '8', '88', '84', '96', '95']
# [1220.0, 3.53, 5.0, 8.0, 88.0, 84.0, 96.0, 95.0]
# True
# ['1310', '3.37', '4', '5', '92', '85', '83', '80']
# [1310.0, 3.37, 4.0, 5.0, 92.0, 85.0, 83.0, 80.0]
# True
# ['1000', '2.62', '1', '0', '90', '89', '89', '97']
# [1000.0, 2.62, 1.0, 0.0, 90.0, 89.0, 89.0, 97.0]
# True
# ['1240', '3.23', '5', '2', '96', '87', '90', '84']
# [1240.0, 3.23, 5.0, 2.0, 96.0, 87.0, 90.0, 84.0]
# True
# ['1380', '3.33', '10', '10', '93', '91', '89', '81']
# [1380.0, 3.33, 10.0, 10.0, 93.0, 91.0, 89.0, 81.0]
# True
# ['1070', '3.01', '1', '10', '92', '81', '94', '87']
# [1070.0, 3.01, 1.0, 10.0, 92.0, 81.0, 94.0, 87.0]
# True
# ['1380', '4.3', '8', '1', '98', '85', '96', '79']
# [1380.0, 4.3, 8.0, 1.0, 98.0, 85.0, 96.0, 79.0]
# True
# ['1560', '3.88', '10', '3', '98', '89', '84', '90']
# [1560.0, 3.88, 10.0, 3.0, 98.0, 89.0, 84.0, 90.0]
# True
# ['1400', '4', '9', '5', '86', '92', '97', '75']
# [1400.0, 4.0, 9.0, 5.0, 86.0, 92.0, 97.0, 75.0]
# True
# ['1320', '3.84', '4', '5', '97', '88', '85', '91']
# [1320.0, 3.84, 4.0, 5.0, 97.0, 88.0, 85.0, 91.0]
# True
# ['950', '2.79', '1', '4', '87', '87', '91', '93']
# [950.0, 2.79, 1.0, 4.0, 87.0, 87.0, 91.0, 93.0]
# True
# ['1380', '3.6', '0', '10', '93', '90', '93', '91']
# [1380.0, 3.6, 0.0, 10.0, 93.0, 90.0, 93.0, 91.0]
# True
# ['1220', '3.61', '6', '10', '96', '82', '89', '95']
# [1220.0, 3.61, 6.0, 10.0, 96.0, 82.0, 89.0, 95.0]
# True
# ['1100', '2.88', '3', '2', '91', '81', '97', '89']
# [1100.0, 2.88, 3.0, 2.0, 91.0, 81.0, 97.0, 89.0]
# True
# ['1190', '3.07', '2', '1', '93', '83', '84', '79']
# [1190.0, 3.07, 2.0, 1.0, 93.0, 83.0, 84.0, 79.0]
# True
# ['1140', '3.35', '7', '3', '90', '90', '91', '81']
# [1140.0, 3.35, 7.0, 3.0, 90.0, 90.0, 91.0, 81.0]
# True
# ['1260', '2.94', '7', '5', '95', '89', '84', '90']
# [1260.0, 2.94, 7.0, 5.0, 95.0, 89.0, 84.0, 90.0]
# True
# ['1400', '3.54', '6', '10', '94', '85', '97', '75']
# [1400.0, 3.54, 6.0, 10.0, 94.0, 85.0, 97.0, 75.0]
# True
# ['1410', '3.76', '4', '7', '87', '87', '83', '93']
# [1410.0, 3.76, 4.0, 7.0, 87.0, 87.0, 83.0, 93.0]
# True
# ['1300', '3.59', '5', '3', '85', '91', '94', '86']
# [1300.0, 3.59, 5.0, 3.0, 85.0, 91.0, 94.0, 86.0]
# True
# ['1260', '3.47', '6', '9', '88', '89', '97', '76']
# [1260.0, 3.47, 6.0, 9.0, 88.0, 89.0, 97.0, 76.0]
# True
# ['1340', '3.59', '10', '9', '92', '92', '84', '92']
# [1340.0, 3.59, 10.0, 9.0, 92.0, 92.0, 84.0, 92.0]
# True
# ['1250', '3.07', '9', '7', '91', '83', '87', '87']
# [1250.0, 3.07, 9.0, 7.0, 91.0, 83.0, 87.0, 87.0]
# True
# ['1100', '3.23', '0', '3', '93', '91', '94', '95']
# [1100.0, 3.23, 0.0, 3.0, 93.0, 91.0, 94.0, 95.0]
# True
# ['1370', '3.63', '9', '4', '92', '86', '89', '87']
# [1370.0, 3.63, 9.0, 4.0, 92.0, 86.0, 89.0, 87.0]
# True
# ['1320', '3.77', '5', '7', '91', '88', '94', '89']
# [1320.0, 3.77, 5.0, 7.0, 91.0, 88.0, 94.0, 89.0]
# True
# ['1160', '3.31', '1', '1', '93', '82', '90', '85']
# [1160.0, 3.31, 1.0, 1.0, 93.0, 82.0, 90.0, 85.0]
# True
# ['1140', '3.2', '2', '10', '94', '88', '87', '66']
# [1140.0, 3.2, 2.0, 10.0, 94.0, 88.0, 87.0, 66.0]
# True
# ['1460', '4', '1', '0', '86', '82', '83', '81']
# [1460.0, 4.0, 1.0, 0.0, 86.0, 82.0, 83.0, 81.0]
# True
# ['1500', '3.92', '9', '1', '87', '89', '86', '80']
# [1500.0, 3.92, 9.0, 1.0, 87.0, 89.0, 86.0, 80.0]
# True
# ['1560', '3.89', '9', '0', '86', '88', '84', '88']
# [1560.0, 3.89, 9.0, 0.0, 86.0, 88.0, 84.0, 88.0]
# True
# ['1490', '3.8', '7', '7', '98', '85', '82', '91']
# [1490.0, 3.8, 7.0, 7.0, 98.0, 85.0, 82.0, 91.0]
# True
# ['1320', '3.54', '10', '4', '86', '83', '96', '93']
# [1320.0, 3.54, 10.0, 4.0, 86.0, 83.0, 96.0, 93.0]
# True
# ['1250', '3.63', '0', '6', '89', '92', '87', '98']
# [1250.0, 3.63, 0.0, 6.0, 89.0, 92.0, 87.0, 98.0]
# True
# ['1190', '3.16', '3', '0', '97', '85', '97', '94']
# [1190.0, 3.16, 3.0, 0.0, 97.0, 85.0, 97.0, 94.0]
# True
# ['1200', '3.5', '1', '3', '87', '81', '86', '96']
# [1200.0, 3.5, 1.0, 3.0, 87.0, 81.0, 86.0, 96.0]
# True
# ['1380', '3.34', '1', '10', '98', '87', '97', '80']
# [1380.0, 3.34, 1.0, 10.0, 98.0, 87.0, 97.0, 80.0]
# True
# ['1260', '3.02', '5', '0', '89', '86', '87', '89']
# [1260.0, 3.02, 5.0, 0.0, 89.0, 86.0, 87.0, 89.0]
# True
# ['1200', '2.87', '1', '3', '85', '84', '98', '61']
# [1200.0, 2.87, 1.0, 3.0, 85.0, 84.0, 98.0, 61.0]
# True
# ['1180', '3.38', '0', '6', '91', '85', '97', '88']
# [1180.0, 3.38, 0.0, 6.0, 91.0, 85.0, 97.0, 88.0]
# True

# %% [markdown]
# ### Task 3
# Separate your data. Use list slicing to separate your list (which should contain 8 numbers at this point) into two lists: one that contains the student's SAT, GPA, Interest, and High School Quality scores, and one that contains their 4 semester grades. You'll do Questions 2 - 4 with the first list of 4 numbers and Question 5 with the list of grades.

# %%
### INSERT YOUR CODE HERE
primary_info = []  
semester_grades = []  

for i in range(len(all_converted_data)):  
    primary_info.append(all_converted_data[i][:4])
    semester_grades.append(all_converted_data[i][4:]) 

for i in range(len(primary_info)):
    print(f" Primary Information = {primary_info[i]}, Semester Grades = {semester_grades[i]}")
# Out:
#  Primary Information = [1300.0, 3.61, 10.0, 7.0], Semester Grades = [95.0, 86.0, 91.0, 94.0]
#  Primary Information = [1400.0, 3.67, 0.0, 9.0], Semester Grades = [97.0, 83.0, 85.0, 86.0]
#  Primary Information = [900.0, 4.0, 5.0, 2.0], Semester Grades = [88.0, 92.0, 83.0, 72.0]
#  Primary Information = [1360.0, 3.19, 0.0, 9.0], Semester Grades = [90.0, 85.0, 97.0, 87.0]
#  Primary Information = [1180.0, 2.93, 2.0, 7.0], Semester Grades = [93.0, 81.0, 90.0, 87.0]
#  Primary Information = [1180.0, 3.0, 6.0, 7.0], Semester Grades = [95.0, 88.0, 97.0, 97.0]
#  Primary Information = [1140.0, 2.98, 10.0, 8.0], Semester Grades = [92.0, 81.0, 95.0, 90.0]
#  Primary Information = [1190.0, 3.08, 1.0, 7.0], Semester Grades = [96.0, 82.0, 83.0, 81.0]
#  Primary Information = [1400.0, 3.39, 10.0, 9.0], Semester Grades = [85.0, 87.0, 92.0, 98.0]
#  Primary Information = [1310.0, 3.92, 8.0, 4.0], Semester Grades = [95.0, 88.0, 87.0, 95.0]
#  Primary Information = [1310.0, 4.0, 1.0, 1.0], Semester Grades = [90.0, 86.0, 81.0, 82.0]
#  Primary Information = [1100.0, 3.22, 10.0, 3.0], Semester Grades = [93.0, 89.0, 94.0, 96.0]
#  Primary Information = [1150.0, 4.6, 9.0, 2.0], Semester Grades = [86.0, 90.0, 83.0, 89.0]
#  Primary Information = [1220.0, 3.08, 7.0, 10.0], Semester Grades = [96.0, 92.0, 81.0, 84.0]
#  Primary Information = [1340.0, 4.0, 2.0, 4.0], Semester Grades = [90.0, 89.0, 95.0, 92.0]
#  Primary Information = [1400.0, 3.44, 10.0, 2.0], Semester Grades = [88.0, 92.0, 85.0, 67.0]
#  Primary Information = [1000.0, 4.2, 3.0, 3.0], Semester Grades = [86.0, 85.0, 86.0, 79.0]
#  Primary Information = [950.0, 2.56, 5.0, 7.0], Semester Grades = [97.0, 88.0, 95.0, 89.0]
#  Primary Information = [1420.0, 3.75, 10.0, 1.0], Semester Grades = [88.0, 83.0, 87.0, 94.0]
#  Primary Information = [1350.0, 3.81, 7.0, 7.0], Semester Grades = [92.0, 86.0, 81.0, 83.0]
#  Primary Information = [1160.0, 3.17, 0.0, 4.0], Semester Grades = [87.0, 87.0, 81.0, 93.0]
#  Primary Information = [1190.0, 3.63, 3.0, 3.0], Semester Grades = [90.0, 91.0, 83.0, 89.0]
#  Primary Information = [950.0, 2.82, 7.0, 3.0], Semester Grades = [88.0, 90.0, 90.0, 82.0]
#  Primary Information = [1200.0, 4.8, 0.0, 1.0], Semester Grades = [90.0, 82.0, 90.0, 93.0]
#  Primary Information = [1250.0, 3.35, 2.0, 9.0], Semester Grades = [97.0, 89.0, 97.0, 89.0]
#  Primary Information = [1420.0, 4.2, 3.0, 2.0], Semester Grades = [97.0, 87.0, 95.0, 98.0]
#  Primary Information = [1380.0, 3.61, 0.0, 7.0], Semester Grades = [96.0, 90.0, 88.0, 94.0]
#  Primary Information = [1500.0, 3.74, 0.0, 0.0], Semester Grades = [92.0, 86.0, 81.0, 90.0]
#  Primary Information = [1240.0, 3.22, 3.0, 10.0], Semester Grades = [97.0, 90.0, 82.0, 98.0]
#  Primary Information = [1090.0, 3.29, 5.0, 8.0], Semester Grades = [95.0, 82.0, 97.0, 76.0]
#  Primary Information = [1530.0, 3.78, 7.0, 4.0], Semester Grades = [95.0, 85.0, 89.0, 94.0]
#  Primary Information = [1310.0, 3.35, 7.0, 9.0], Semester Grades = [89.0, 87.0, 83.0, 55.0]
#  Primary Information = [1180.0, 3.4, 9.0, 9.0], Semester Grades = [93.0, 84.0, 90.0, 96.0]
#  Primary Information = [1520.0, 4.35, 5.0, 3.0], Semester Grades = [94.0, 85.0, 84.0, 81.0]
#  Primary Information = [1200.0, 4.9, 10.0, 1.0], Semester Grades = [87.0, 89.0, 97.0, 85.0]
#  Primary Information = [1190.0, 3.05, 8.0, 7.0], Semester Grades = [94.0, 91.0, 98.0, 93.0]
#  Primary Information = [1240.0, 3.25, 2.0, 2.0], Semester Grades = [86.0, 83.0, 90.0, 92.0]
#  Primary Information = [1260.0, 2.9, 0.0, 0.0], Semester Grades = [94.0, 85.0, 82.0, 89.0]
#  Primary Information = [1180.0, 3.13, 8.0, 6.0], Semester Grades = [86.0, 83.0, 97.0, 82.0]
#  Primary Information = [1200.0, 2.68, 9.0, 1.0], Semester Grades = [90.0, 88.0, 86.0, 80.0]
#  Primary Information = [1050.0, 2.42, 5.0, 4.0], Semester Grades = [93.0, 90.0, 92.0, 98.0]
#  Primary Information = [1330.0, 3.32, 8.0, 8.0], Semester Grades = [97.0, 87.0, 97.0, 87.0]
#  Primary Information = [1210.0, 3.15, 0.0, 9.0], Semester Grades = [91.0, 91.0, 85.0, 96.0]
#  Primary Information = [1280.0, 3.31, 10.0, 3.0], Semester Grades = [92.0, 91.0, 87.0, 80.0]
#  Primary Information = [1260.0, 2.94, 1.0, 9.0], Semester Grades = [91.0, 92.0, 96.0, 96.0]
#  Primary Information = [1140.0, 3.45, 1.0, 10.0], Semester Grades = [85.0, 87.0, 95.0, 94.0]
#  Primary Information = [1250.0, 3.46, 4.0, 3.0], Semester Grades = [86.0, 88.0, 85.0, 77.0]
#  Primary Information = [1160.0, 2.97, 10.0, 9.0], Semester Grades = [88.0, 82.0, 95.0, 83.0]
#  Primary Information = [1140.0, 2.48, 8.0, 5.0], Semester Grades = [94.0, 81.0, 89.0, 82.0]
#  Primary Information = [1290.0, 3.35, 0.0, 0.0], Semester Grades = [91.0, 82.0, 82.0, 77.0]
#  Primary Information = [1360.0, 3.86, 8.0, 3.0], Semester Grades = [96.0, 82.0, 97.0, 79.0]
#  Primary Information = [1080.0, 3.13, 10.0, 5.0], Semester Grades = [85.0, 86.0, 96.0, 90.0]
#  Primary Information = [1370.0, 3.37, 5.0, 4.0], Semester Grades = [88.0, 87.0, 83.0, 87.0]
#  Primary Information = [1170.0, 3.27, 4.0, 10.0], Semester Grades = [89.0, 92.0, 97.0, 87.0]
#  Primary Information = [1260.0, 3.34, 4.0, 0.0], Semester Grades = [98.0, 85.0, 89.0, 82.0]
#  Primary Information = [1370.0, 4.0, 3.0, 7.0], Semester Grades = [86.0, 85.0, 97.0, 81.0]
#  Primary Information = [1250.0, 3.19, 0.0, 10.0], Semester Grades = [91.0, 84.0, 92.0, 93.0]
#  Primary Information = [1090.0, 2.94, 5.0, 5.0], Semester Grades = [97.0, 83.0, 87.0, 82.0]
#  Primary Information = [1380.0, 3.65, 5.0, 3.0], Semester Grades = [93.0, 82.0, 93.0, 61.0]
#  Primary Information = [1150.0, 2.82, 6.0, 0.0], Semester Grades = [97.0, 85.0, 84.0, 92.0]
#  Primary Information = [1210.0, 3.18, 9.0, 1.0], Semester Grades = [86.0, 91.0, 90.0, 80.0]
#  Primary Information = [1100.0, 3.32, 8.0, 6.0], Semester Grades = [94.0, 89.0, 98.0, 85.0]
#  Primary Information = [950.0, 4.1, 0.0, 2.0], Semester Grades = [85.0, 86.0, 97.0, 81.0]
#  Primary Information = [1560.0, 3.85, 10.0, 8.0], Semester Grades = [94.0, 86.0, 87.0, 89.0]
#  Primary Information = [1430.0, 4.0, 1.0, 2.0], Semester Grades = [94.0, 85.0, 98.0, 92.0]
#  Primary Information = [1420.0, 3.59, 5.0, 1.0], Semester Grades = [85.0, 92.0, 81.0, 94.0]
#  Primary Information = [1330.0, 3.62, 3.0, 9.0], Semester Grades = [97.0, 86.0, 93.0, 90.0]
#  Primary Information = [1170.0, 3.3, 6.0, 2.0], Semester Grades = [97.0, 86.0, 82.0, 56.0]
#  Primary Information = [1460.0, 3.69, 9.0, 10.0], Semester Grades = [92.0, 83.0, 88.0, 92.0]
#  Primary Information = [1310.0, 3.73, 3.0, 5.0], Semester Grades = [86.0, 86.0, 94.0, 77.0]
#  Primary Information = [1320.0, 4.0, 7.0, 6.0], Semester Grades = [94.0, 92.0, 89.0, 75.0]
#  Primary Information = [1130.0, 2.92, 3.0, 1.0], Semester Grades = [97.0, 86.0, 95.0, 91.0]
#  Primary Information = [1180.0, 3.39, 8.0, 0.0], Semester Grades = [95.0, 84.0, 91.0, 88.0]
#  Primary Information = [1490.0, 4.0, 10.0, 6.0], Semester Grades = [97.0, 90.0, 89.0, 85.0]
#  Primary Information = [1290.0, 3.45, 8.0, 9.0], Semester Grades = [98.0, 83.0, 86.0, 80.0]
#  Primary Information = [1340.0, 4.0, 10.0, 4.0], Semester Grades = [98.0, 88.0, 88.0, 85.0]
#  Primary Information = [1290.0, 3.36, 9.0, 8.0], Semester Grades = [87.0, 84.0, 97.0, 81.0]
#  Primary Information = [1350.0, 4.0, 3.0, 8.0], Semester Grades = [93.0, 83.0, 85.0, 96.0]
#  Primary Information = [1100.0, 3.12, 9.0, 10.0], Semester Grades = [93.0, 82.0, 95.0, 86.0]
#  Primary Information = [1410.0, 4.0, 7.0, 10.0], Semester Grades = [85.0, 90.0, 91.0, 79.0]
#  Primary Information = [1140.0, 2.9, 5.0, 7.0], Semester Grades = [93.0, 83.0, 86.0, 92.0]
#  Primary Information = [1160.0, 3.07, 4.0, 6.0], Semester Grades = [87.0, 82.0, 92.0, 75.0]
#  Primary Information = [1080.0, 2.71, 3.0, 1.0], Semester Grades = [96.0, 82.0, 96.0, 50.0]
#  Primary Information = [1090.0, 2.91, 3.0, 4.0], Semester Grades = [92.0, 88.0, 84.0, 78.0]
#  Primary Information = [1150.0, 4.7, 2.0, 3.0], Semester Grades = [91.0, 85.0, 94.0, 93.0]
#  Primary Information = [1090.0, 2.98, 6.0, 10.0], Semester Grades = [96.0, 84.0, 90.0, 81.0]
#  Primary Information = [1370.0, 4.1, 6.0, 8.0], Semester Grades = [87.0, 91.0, 94.0, 77.0]
#  Primary Information = [1330.0, 3.48, 1.0, 2.0], Semester Grades = [87.0, 87.0, 88.0, 96.0]
#  Primary Information = [1370.0, 3.28, 0.0, 7.0], Semester Grades = [95.0, 91.0, 90.0, 80.0]
#  Primary Information = [1520.0, 4.0, 0.0, 10.0], Semester Grades = [86.0, 87.0, 86.0, 88.0]
#  Primary Information = [1520.0, 3.83, 10.0, 0.0], Semester Grades = [91.0, 83.0, 90.0, 75.0]
#  Primary Information = [1220.0, 3.64, 7.0, 6.0], Semester Grades = [92.0, 83.0, 81.0, 98.0]
#  Primary Information = [1550.0, 3.9, 6.0, 3.0], Semester Grades = [98.0, 81.0, 82.0, 97.0]
#  Primary Information = [1170.0, 2.93, 8.0, 0.0], Semester Grades = [86.0, 86.0, 88.0, 79.0]
#  Primary Information = [1280.0, 3.44, 5.0, 3.0], Semester Grades = [94.0, 90.0, 85.0, 84.0]
#  Primary Information = [1110.0, 3.33, 2.0, 6.0], Semester Grades = [90.0, 86.0, 93.0, 98.0]
#  Primary Information = [1180.0, 3.52, 5.0, 9.0], Semester Grades = [91.0, 92.0, 96.0, 95.0]
#  Primary Information = [1240.0, 3.57, 6.0, 9.0], Semester Grades = [89.0, 92.0, 82.0, 81.0]
#  Primary Information = [1120.0, 2.88, 0.0, 5.0], Semester Grades = [96.0, 82.0, 84.0, 58.0]
#  Primary Information = [1140.0, 3.31, 4.0, 0.0], Semester Grades = [91.0, 87.0, 82.0, 90.0]
#  Primary Information = [1310.0, 3.15, 10.0, 10.0], Semester Grades = [97.0, 86.0, 97.0, 77.0]
#  Primary Information = [1400.0, 3.57, 7.0, 2.0], Semester Grades = [95.0, 81.0, 95.0, 95.0]
#  Primary Information = [1290.0, 3.33, 0.0, 4.0], Semester Grades = [98.0, 84.0, 94.0, 84.0]
#  Primary Information = [1150.0, 4.7, 6.0, 4.0], Semester Grades = [96.0, 90.0, 82.0, 87.0]
#  Primary Information = [1450.0, 3.95, 6.0, 7.0], Semester Grades = [95.0, 81.0, 94.0, 86.0]
#  Primary Information = [1000.0, 2.97, 8.0, 10.0], Semester Grades = [86.0, 88.0, 90.0, 86.0]
#  Primary Information = [1310.0, 3.56, 4.0, 0.0], Semester Grades = [90.0, 87.0, 98.0, 90.0]
#  Primary Information = [1170.0, 3.13, 7.0, 4.0], Semester Grades = [92.0, 89.0, 94.0, 77.0]
#  Primary Information = [1180.0, 2.93, 5.0, 9.0], Semester Grades = [85.0, 92.0, 93.0, 83.0]
#  Primary Information = [1370.0, 3.45, 10.0, 8.0], Semester Grades = [94.0, 83.0, 91.0, 84.0]
#  Primary Information = [1160.0, 3.08, 0.0, 6.0], Semester Grades = [91.0, 86.0, 82.0, 93.0]
#  Primary Information = [1140.0, 3.41, 3.0, 10.0], Semester Grades = [86.0, 87.0, 98.0, 90.0]
#  Primary Information = [1190.0, 3.0, 6.0, 3.0], Semester Grades = [93.0, 86.0, 88.0, 98.0]
#  Primary Information = [1310.0, 3.22, 0.0, 5.0], Semester Grades = [85.0, 81.0, 89.0, 90.0]
#  Primary Information = [1300.0, 3.84, 3.0, 4.0], Semester Grades = [87.0, 89.0, 92.0, 78.0]
#  Primary Information = [1490.0, 3.99, 1.0, 5.0], Semester Grades = [94.0, 84.0, 84.0, 90.0]
#  Primary Information = [1250.0, 3.45, 3.0, 10.0], Semester Grades = [93.0, 81.0, 88.0, 90.0]
#  Primary Information = [1460.0, 3.72, 8.0, 6.0], Semester Grades = [87.0, 83.0, 94.0, 96.0]
#  Primary Information = [1510.0, 3.7, 3.0, 0.0], Semester Grades = [88.0, 86.0, 82.0, 84.0]
#  Primary Information = [1060.0, 2.92, 0.0, 9.0], Semester Grades = [91.0, 89.0, 87.0, 96.0]
#  Primary Information = [1410.0, 3.74, 8.0, 6.0], Semester Grades = [98.0, 92.0, 84.0, 86.0]
#  Primary Information = [1160.0, 2.67, 2.0, 5.0], Semester Grades = [91.0, 89.0, 82.0, 81.0]
#  Primary Information = [1050.0, 2.85, 6.0, 4.0], Semester Grades = [87.0, 91.0, 90.0, 85.0]
#  Primary Information = [1010.0, 4.25, 6.0, 4.0], Semester Grades = [93.0, 86.0, 93.0, 65.0]
#  Primary Information = [1470.0, 3.88, 9.0, 4.0], Semester Grades = [88.0, 84.0, 89.0, 96.0]
#  Primary Information = [1380.0, 3.38, 10.0, 4.0], Semester Grades = [93.0, 88.0, 83.0, 84.0]
#  Primary Information = [1190.0, 3.54, 8.0, 1.0], Semester Grades = [95.0, 85.0, 81.0, 88.0]
#  Primary Information = [1410.0, 3.74, 7.0, 0.0], Semester Grades = [87.0, 86.0, 95.0, 75.0]
#  Primary Information = [1310.0, 3.19, 1.0, 9.0], Semester Grades = [88.0, 91.0, 93.0, 98.0]
#  Primary Information = [1080.0, 3.15, 7.0, 4.0], Semester Grades = [91.0, 86.0, 83.0, 82.0]
#  Primary Information = [1270.0, 3.17, 0.0, 1.0], Semester Grades = [92.0, 83.0, 86.0, 91.0]
#  Primary Information = [1190.0, 2.79, 5.0, 7.0], Semester Grades = [94.0, 82.0, 88.0, 82.0]
#  Primary Information = [1140.0, 3.4, 8.0, 7.0], Semester Grades = [90.0, 90.0, 87.0, 76.0]
#  Primary Information = [1230.0, 3.08, 10.0, 0.0], Semester Grades = [86.0, 92.0, 87.0, 82.0]
#  Primary Information = [1090.0, 2.95, 7.0, 3.0], Semester Grades = [87.0, 86.0, 93.0, 75.0]
#  Primary Information = [1400.0, 3.57, 6.0, 4.0], Semester Grades = [97.0, 92.0, 85.0, 94.0]
#  Primary Information = [1260.0, 3.33, 5.0, 2.0], Semester Grades = [87.0, 90.0, 96.0, 75.0]
#  Primary Information = [1590.0, 4.0, 3.0, 2.0], Semester Grades = [97.0, 91.0, 88.0, 78.0]
#  Primary Information = [1190.0, 3.4, 1.0, 9.0], Semester Grades = [96.0, 86.0, 92.0, 88.0]
#  Primary Information = [1220.0, 3.58, 5.0, 9.0], Semester Grades = [85.0, 92.0, 94.0, 94.0]
#  Primary Information = [1470.0, 3.93, 7.0, 8.0], Semester Grades = [97.0, 88.0, 86.0, 83.0]
#  Primary Information = [1420.0, 3.52, 7.0, 1.0], Semester Grades = [88.0, 82.0, 98.0, 75.0]
#  Primary Information = [1380.0, 3.94, 10.0, 0.0], Semester Grades = [98.0, 91.0, 94.0, 90.0]
#  Primary Information = [1260.0, 3.4, 10.0, 2.0], Semester Grades = [94.0, 81.0, 94.0, 97.0]
#  Primary Information = [1380.0, 3.4, 5.0, 3.0], Semester Grades = [96.0, 82.0, 81.0, 89.0]
#  Primary Information = [1410.0, 3.43, 1.0, 10.0], Semester Grades = [92.0, 82.0, 93.0, 87.0]
#  Primary Information = [1300.0, 3.4, 10.0, 5.0], Semester Grades = [86.0, 86.0, 91.0, 92.0]
#  Primary Information = [940.0, 2.71, 9.0, 9.0], Semester Grades = [97.0, 83.0, 97.0, 98.0]
#  Primary Information = [1150.0, 2.91, 0.0, 5.0], Semester Grades = [92.0, 86.0, 92.0, 83.0]
#  Primary Information = [1290.0, 3.31, 1.0, 8.0], Semester Grades = [89.0, 84.0, 86.0, 86.0]
#  Primary Information = [1330.0, 3.74, 5.0, 10.0], Semester Grades = [90.0, 91.0, 86.0, 78.0]
#  Primary Information = [1280.0, 3.38, 0.0, 4.0], Semester Grades = [98.0, 81.0, 89.0, 76.0]
#  Primary Information = [1510.0, 3.94, 5.0, 1.0], Semester Grades = [88.0, 84.0, 97.0, 82.0]
#  Primary Information = [1140.0, 3.46, 10.0, 0.0], Semester Grades = [96.0, 83.0, 93.0, 86.0]
#  Primary Information = [1440.0, 3.69, 2.0, 5.0], Semester Grades = [90.0, 91.0, 85.0, 78.0]
#  Primary Information = [980.0, 2.86, 0.0, 3.0], Semester Grades = [97.0, 92.0, 96.0, 85.0]
#  Primary Information = [930.0, 2.52, 7.0, 0.0], Semester Grades = [88.0, 82.0, 81.0, 75.0]
#  Primary Information = [1260.0, 3.58, 6.0, 4.0], Semester Grades = [92.0, 83.0, 93.0, 89.0]
#  Primary Information = [1280.0, 3.49, 10.0, 2.0], Semester Grades = [96.0, 81.0, 84.0, 84.0]
#  Primary Information = [1470.0, 3.82, 8.0, 5.0], Semester Grades = [86.0, 82.0, 89.0, 90.0]
#  Primary Information = [1200.0, 3.13, 4.0, 8.0], Semester Grades = [98.0, 82.0, 89.0, 91.0]
#  Primary Information = [1370.0, 3.5, 2.0, 2.0], Semester Grades = [88.0, 88.0, 87.0, 76.0]
#  Primary Information = [1220.0, 3.56, 3.0, 10.0], Semester Grades = [92.0, 91.0, 83.0, 89.0]
#  Primary Information = [1060.0, 2.73, 4.0, 4.0], Semester Grades = [91.0, 85.0, 88.0, 79.0]
#  Primary Information = [1200.0, 4.9, 10.0, 1.0], Semester Grades = [86.0, 92.0, 89.0, 79.0]
#  Primary Information = [1440.0, 4.0, 3.0, 10.0], Semester Grades = [91.0, 91.0, 81.0, 83.0]
#  Primary Information = [1210.0, 3.24, 9.0, 5.0], Semester Grades = [94.0, 82.0, 83.0, 94.0]
#  Primary Information = [1480.0, 3.77, 0.0, 10.0], Semester Grades = [98.0, 91.0, 85.0, 86.0]
#  Primary Information = [1420.0, 4.0, 10.0, 8.0], Semester Grades = [98.0, 91.0, 98.0, 76.0]
#  Primary Information = [1390.0, 3.62, 9.0, 5.0], Semester Grades = [90.0, 92.0, 89.0, 94.0]
#  Primary Information = [1200.0, 3.51, 2.0, 9.0], Semester Grades = [85.0, 86.0, 90.0, 89.0]
#  Primary Information = [1160.0, 2.81, 0.0, 1.0], Semester Grades = [97.0, 86.0, 94.0, 96.0]
#  Primary Information = [1380.0, 3.48, 9.0, 10.0], Semester Grades = [90.0, 83.0, 81.0, 84.0]
#  Primary Information = [1320.0, 3.43, 0.0, 6.0], Semester Grades = [95.0, 86.0, 83.0, 88.0]
#  Primary Information = [1220.0, 3.53, 5.0, 8.0], Semester Grades = [88.0, 84.0, 96.0, 95.0]
#  Primary Information = [1310.0, 3.37, 4.0, 5.0], Semester Grades = [92.0, 85.0, 83.0, 80.0]
#  Primary Information = [1000.0, 2.62, 1.0, 0.0], Semester Grades = [90.0, 89.0, 89.0, 97.0]
#  Primary Information = [1240.0, 3.23, 5.0, 2.0], Semester Grades = [96.0, 87.0, 90.0, 84.0]
#  Primary Information = [1380.0, 3.33, 10.0, 10.0], Semester Grades = [93.0, 91.0, 89.0, 81.0]
#  Primary Information = [1070.0, 3.01, 1.0, 10.0], Semester Grades = [92.0, 81.0, 94.0, 87.0]
#  Primary Information = [1380.0, 4.3, 8.0, 1.0], Semester Grades = [98.0, 85.0, 96.0, 79.0]
#  Primary Information = [1560.0, 3.88, 10.0, 3.0], Semester Grades = [98.0, 89.0, 84.0, 90.0]
#  Primary Information = [1400.0, 4.0, 9.0, 5.0], Semester Grades = [86.0, 92.0, 97.0, 75.0]
#  Primary Information = [1320.0, 3.84, 4.0, 5.0], Semester Grades = [97.0, 88.0, 85.0, 91.0]
#  Primary Information = [950.0, 2.79, 1.0, 4.0], Semester Grades = [87.0, 87.0, 91.0, 93.0]
#  Primary Information = [1380.0, 3.6, 0.0, 10.0], Semester Grades = [93.0, 90.0, 93.0, 91.0]
#  Primary Information = [1220.0, 3.61, 6.0, 10.0], Semester Grades = [96.0, 82.0, 89.0, 95.0]
#  Primary Information = [1100.0, 2.88, 3.0, 2.0], Semester Grades = [91.0, 81.0, 97.0, 89.0]
#  Primary Information = [1190.0, 3.07, 2.0, 1.0], Semester Grades = [93.0, 83.0, 84.0, 79.0]
#  Primary Information = [1140.0, 3.35, 7.0, 3.0], Semester Grades = [90.0, 90.0, 91.0, 81.0]
#  Primary Information = [1260.0, 2.94, 7.0, 5.0], Semester Grades = [95.0, 89.0, 84.0, 90.0]
#  Primary Information = [1400.0, 3.54, 6.0, 10.0], Semester Grades = [94.0, 85.0, 97.0, 75.0]
#  Primary Information = [1410.0, 3.76, 4.0, 7.0], Semester Grades = [87.0, 87.0, 83.0, 93.0]
#  Primary Information = [1300.0, 3.59, 5.0, 3.0], Semester Grades = [85.0, 91.0, 94.0, 86.0]
#  Primary Information = [1260.0, 3.47, 6.0, 9.0], Semester Grades = [88.0, 89.0, 97.0, 76.0]
#  Primary Information = [1340.0, 3.59, 10.0, 9.0], Semester Grades = [92.0, 92.0, 84.0, 92.0]
#  Primary Information = [1250.0, 3.07, 9.0, 7.0], Semester Grades = [91.0, 83.0, 87.0, 87.0]
#  Primary Information = [1100.0, 3.23, 0.0, 3.0], Semester Grades = [93.0, 91.0, 94.0, 95.0]
#  Primary Information = [1370.0, 3.63, 9.0, 4.0], Semester Grades = [92.0, 86.0, 89.0, 87.0]
#  Primary Information = [1320.0, 3.77, 5.0, 7.0], Semester Grades = [91.0, 88.0, 94.0, 89.0]
#  Primary Information = [1160.0, 3.31, 1.0, 1.0], Semester Grades = [93.0, 82.0, 90.0, 85.0]
#  Primary Information = [1140.0, 3.2, 2.0, 10.0], Semester Grades = [94.0, 88.0, 87.0, 66.0]
#  Primary Information = [1460.0, 4.0, 1.0, 0.0], Semester Grades = [86.0, 82.0, 83.0, 81.0]
#  Primary Information = [1500.0, 3.92, 9.0, 1.0], Semester Grades = [87.0, 89.0, 86.0, 80.0]
#  Primary Information = [1560.0, 3.89, 9.0, 0.0], Semester Grades = [86.0, 88.0, 84.0, 88.0]
#  Primary Information = [1490.0, 3.8, 7.0, 7.0], Semester Grades = [98.0, 85.0, 82.0, 91.0]
#  Primary Information = [1320.0, 3.54, 10.0, 4.0], Semester Grades = [86.0, 83.0, 96.0, 93.0]
#  Primary Information = [1250.0, 3.63, 0.0, 6.0], Semester Grades = [89.0, 92.0, 87.0, 98.0]
#  Primary Information = [1190.0, 3.16, 3.0, 0.0], Semester Grades = [97.0, 85.0, 97.0, 94.0]
#  Primary Information = [1200.0, 3.5, 1.0, 3.0], Semester Grades = [87.0, 81.0, 86.0, 96.0]
#  Primary Information = [1380.0, 3.34, 1.0, 10.0], Semester Grades = [98.0, 87.0, 97.0, 80.0]
#  Primary Information = [1260.0, 3.02, 5.0, 0.0], Semester Grades = [89.0, 86.0, 87.0, 89.0]
#  Primary Information = [1200.0, 2.87, 1.0, 3.0], Semester Grades = [85.0, 84.0, 98.0, 61.0]
#  Primary Information = [1180.0, 3.38, 0.0, 6.0], Semester Grades = [91.0, 85.0, 97.0, 88.0]

# %% [markdown]
# ### **Question 2 - Prospective Student Score (15 points)**
# ### Task 1
#
# Write a function `calculate_score()` that takes a list as a parameter and calculates an overall score for each student based on the following weights:
#
# - 30% SAT
# - 40% GPA
# - 10% demonstrated interest
# - 20% strength of curriculum
#
# The list parameter will contain all of the relevant information about the student. The return value is the student’s calculated score. To make this work, you will also need to normalize both GPA and SAT so that they are also on a 0 to 10 scale. To do this, multiply the GPA by 2, and divide the SAT score by 160.
#
# Example:
#
# > Input: [1300.0, 3.61, 10.0, 7.0] - which represents a student with a 1300 SAT score, a 3.61 GPA, 10 out of 10 for interest and 7 out of 10 for high school quality
# >
# > Output: ((1300 / 160) * 0.3) + ((3.61 * 2) * 0.4) + (10 * 0.1) + (7 * 0.2) = 7.73 out of 10
#
# Round your final output score to 2 decimal places. This can be done following the example:
#
# > `name = "Dr. Stephens"`
# >
# > `score = 7.1`
# >
# > `print(f"{name},{score:.2f}")`
#
# This will print "Dr. Stephens,7.10"
#
# You start the formatted string with an `f`, then enclose the variables in curly braces {}. The `:.2f` tells the formatter to print the variable as a floating point number with 2 digits after the decimal point (`.`). You can use these formatted strings anywhere you would use a string, i.e. print(), write(), & assignment statements, etc.

# %%
### INSERT YOUR CODE HERE
def calculate_score(student_info):
    
    sat = student_info[0] / 160  
    gpa = student_info[1] * 2  
    interest = student_info[2]  
    high_school_quality = student_info[3] 

    score = (sat * 0.3) + (gpa * 0.4) + (interest * 0.1) + (high_school_quality * 0.2)
    
    return round(score, 2)  
    
student_scores = []

for i in range(len(student_names)):  
    student_name = student_names[i] 
    student_score = calculate_score(primary_info[i])
    student_scores.append(student_score)

    print(f"{student_name},{student_score:.2f}")
# Out:
# Abbess Horror ,7.73
# Adele Hawthorne ,7.36
# Adelicia von Krupp ,5.79
# Adriana Soria ,6.90
# Adriana Princess,6.16
# Adrienne Frost ,6.61
# Agatha Timly ,7.12
# Agent Anesthesia ,6.20
# Aghanne Buffalo,8.14
# Aguja Buffalo,7.19
# Akira Kiamata ,5.96
# Alaisa Ruatha Pethnan ,6.24
# Alchemist Student,7.14
# Aldebron James,7.45
# Aleksandra Nikolaevna ,6.71
# Alflyse Freshman,6.78
# Alice Hayes ,6.13
# Alice Nugent ,5.73
# Alice Tremaine ,6.86
# Alizon Baunacha ,7.68
# Alkhema Salad,5.51
# Allatou Buffalo,6.04
# Alma Chalmers ,5.34
# Amanda Mueller ,6.29
# Amber Alexis ,7.02
# Amie Zamborano ,6.72
# Amity Hunter ,6.88
# Anastasia Kravinoff ,5.80
# Anastasia Summit ,7.20
# Andrea Haggard ,6.78
# Andrea Janson ,7.39
# Andrea Roarke ,7.64
# Andrea von Strucker ,7.63
# Angela Bradford ,7.43
# Angela Golden ,7.37
# Angelina Brancale ,6.87
# Angeline Kutter ,5.53
# Anita Ehren ,4.68
# Ann Fraley ,6.72
# Ann Herd ,5.49
# Anna Frankenstein ,5.20
# Anne Mutant ,7.55
# Anne Marie Cortez ,6.59
# Anzhela Federova ,6.65
# Aranda Charboneau ,6.61
# Araoha Tepania ,7.00
# Ariana Saddiqi ,6.11
# Arianna Jankos ,7.35
# Ariel Tremmore ,5.92
# Asahiri Aoki ,5.10
# Astrid Bloom ,7.04
# Astrid Mordo ,6.53
# Augusta Seger ,6.56
# Aunt Serr ,7.21
# Axis Annie ,5.43
# Ayla Ranefer ,7.47
# Baba Yaga ,6.90
# Barbara Gruber ,5.90
# Baylee Ann ,6.61
# Beatrix Keener ,5.01
# Belinda Mathius ,5.91
# Belle Raven ,6.72
# Benazir Kaur ,5.46
# Betty Sumitro ,8.61
# Betty Swanson ,6.38
# Beverly Cross ,6.23
# Bianca LaNeige ,7.49
# Big Mother ,5.83
# Black Knight,8.59
# Black Lotus ,6.74
# Black Mariah ,7.58
# Blackwing Smith,4.95
# Blanche Sitznski ,5.72
# Bloody Bess ,8.19
# Bloody Mary ,7.78
# Blow Dryer ,7.51
# Bombardier ,7.61
# Boudica Gorman ,7.63
# Bouncing Betty ,7.46
# Bridget Malone ,8.54
# Brigitte Lahti ,6.36
# Bronwen Gryffn ,6.23
# Bubbles O'Day ,4.69
# Cal'syee Neramani ,5.47
# Calypso Ezili ,6.72
# Carmella Unuscione ,7.03
# Carol Hines ,8.05
# Carolina Washington ,5.78
# Caroline le Fay ,6.59
# Carolyn Trainer ,8.05
# Cassandra Nova Xavier ,6.91
# Cassandra Pike ,7.10
# Cassandra Romulus ,7.23
# Cat Woman ,5.34
# Cat's Paw ,6.25
# Catastrophe Jen ,6.15
# Catherine D'Antan ,7.33
# Catherine Saint ,7.58
# Catherine Wilder ,5.40
# Cathode ,5.19
# Celestia Denton ,7.98
# Chancellor Cassandra ,6.58
# Charlotte Witter ,5.88
# Cheer Chadwick ,7.32
# Chiquita Tarantula ,7.88
# Christina Carr ,7.05
# Cinder Fontatine ,5.70
# Claudine Renko ,6.20
# Clemence Duval ,6.86
# Coral Ravens,7.93
# Countess Kyra ,5.84
# Countess Mara ,7.17
# Crimson Commando,5.83
# Cristal Lemieux ,6.03
# Criti Noll ,6.61
# Cylla Markham ,7.09
# Cyndi Legion,7.40
# Dagny Forrester ,7.71
# Daisy Villain ,6.09
# Dame Kackle ,6.12
# Dancing Water ,7.64
# Danielle Belmonde ,5.51
# Danielle Blunt ,5.65
# Danielle Forte ,6.69
# Danielle Nicolle ,7.56
# Elena King ,7.09
# Elena von Lundt ,6.06
# Eleven Rupinski,6.34
# Elianne Turac ,6.91
# Elinor von Drei ,6.04
# Elisbeth von Strucker ,5.12
# Elise Winters ,6.36
# Elizabeth Bliss ,7.06
# Elizabeth Braddock,5.77
# Elizabeth Lockhart ,5.70
# Elizabeth Rawson ,6.88
# Elsie Carson ,5.93
# Elspeth Cromwell ,6.88
# Elyse Nelson ,6.85
# Elysia Smith,7.45
# Emma Frost ,8.20
# Emma Steed ,6.38
# Empress Brood ,6.74
# Eradica Smith,6.48
# Ereshkigal Goddess ,6.41
# Erica Fortune ,7.49
# Erica von Kampf ,7.16
# Erica Wolfmann ,6.63
# Erika Benson ,5.48
# Erin Cicero ,6.77
# Lilith Moll ,7.99
# Lillian von Loont ,5.90
# Lily Cromwell ,6.68
# Lily Hollister ,5.91
# Linda Lewis,6.85
# Linda Wei ,4.73
# Linette Martinez ,4.46
# Lisabeth Borden ,6.63
# Livilla Smith,6.59
# Liza Pyne ,7.61
# Llyra Morris ,6.75
# Loca Inferno,5.97
# Lois Smith,7.44
# Lois London ,5.37
# Lola Smith,7.37
# Lorelei Asgardian,8.20
# Lorelei Riciardi ,6.76
# Lorena Haam ,7.79
# Lorina Dodson ,8.46
# Lottie Eikenski ,7.40
# Lotus Newmark ,7.06
# Lou Dade ,4.62
# Lucia von Bardas ,8.27
# Luciane d'Hiver ,6.42
# Lucrezia Borgia ,7.21
# Lupa Lupoff ,6.55
# Lupe Werewolf,4.07
# Lydia Kenny ,5.81
# Lynn Church ,8.25
# Lyudmila Antonovna Kudrin ,6.51
# Ma Mayhem ,7.03
# Madam Qwa ,7.63
# Madam Rapier ,7.73
# Madam Satan ,6.95
# Madam Slay ,4.91
# Madam Swabada ,7.47
# Madam Web ,7.78
# Madam Worm ,5.07
# Madame Death ,5.09
# Madame Hydra,6.12
# Madame Joy ,6.41
# Madame la Morte ,8.06
# Madame Macabre ,7.45
# Madame Mauser ,6.41
# Madame Reneau ,7.54
# Madelyne Pryor ,8.18
# Maggie Langella ,7.10
# Maguire Beck ,5.25
# Majeston Zelia ,7.17
# Maki Matsumoto ,7.39
# Malice Marauders,5.12
# Malon Estella Reeves ,6.90
# Mamalu Buffalo,6.04
# Manchuria Mary ,7.05
# Mantis Reborn,6.94
# Marabeth Buffalo,7.93
# Maraud Buffalo,7.11
# Marci Camp ,6.45
# Marge Smith ,5.06
# Marguerita Buffalo,5.75
# Maria Callasantos ,7.36
# Mariah Ellenthorpe ,5.28
# Marian Pouncy ,5.25
# Marie Batroc ,6.12

# %% [markdown]
# ### Task 2
# Call the `calculate_score()` function for each line (row) of data (after you've converted it). Then, write the student's name and their calculated score to a new file called `student_scores.csv` such that each row contains a student’s name and their score, separated by a comma.
#
# Example:
#
# > Abbess Horror , 1300, 3.61, 10, 7, 95, 86, 91, 94
# >
# > Adele Hawthorne , 1400, 3.67, 0, 9, 97, 83, 85, 86
# >
# > Adelicia von Krupp , 900, 4, 5, 2, 88, 92, 83, 72
#
# lines written to file:
#
# > Abbess Horror , 7.73
# >
# > Adele Hawthorne , 7.36
# >
# > Adelicia von Krupp , 5.79

# %%
### INSERT YOUR CODE HERE
output_filename = "student_scores.csv"

with open(output_filename, "w") as output_file:  
    output_file.write("Student,Score\n") 
    
    for i in range(len(student_names)):  
        student_name = student_names[i]  
        student_score = calculate_score(primary_info[i]) 
        
        output_file.write(f"{student_name},{student_score:.2f}\n")

# %% [markdown]
# Check the `student_scores.csv` file you just create, and print out the answers to the following 3 questions:
# - who gets the highest score after calculation, and what is the score?
# - who gets the lowest score after calculation, and what is the score?
# - what is the average score among all students? Round the results to 2 decimal places.

# %%
### INSERT YOUR CODE HERE
input_filename = "student_scores.csv"

students = []
scores = []

with open(input_filename, "r") as file:
    next(file) 
    for line in file:
        name, score = line.strip().split(",")
        score = float(score)  
        students.append(name)
        scores.append(score)

max_index = scores.index(max(scores)) 
min_index = scores.index(min(scores))  
average_score = round(sum(scores) / len(scores), 2)

print(f" Highest Score: {students[max_index]}, {scores[max_index]:.2f}")
print(f" Lowest Score: {students[min_index]}, {scores[min_index]:.2f}")
print(f" Average Score: {average_score:.2f}")
# Out:
#  Highest Score: Betty Sumitro , 8.61
#  Lowest Score: Lupe Werewolf, 4.07
#  Average Score: 6.65

# %% [markdown]
# ### Task 3
# Write the names for all students who have a score of 6 or higher to a file called `chosen_students.csv`.
#
# Example:
#
# > Abbess Horror , 1300, 3.61, 10, 7, 95, 86, 91, 94
# >
# > Adele Hawthorne , 1400, 3.67, 0, 9, 97, 83, 85, 86
# >
# > Adelicia von Krupp , 900, 4, 5, 2, 88, 92, 83, 72
#
# lines written to file:
#
# > Abbess Horror
# >
# > Adele Hawthorne
#
# Make sure to close all the files you opened in your program.

# %%
### INSERT YOUR CODE HERE
input_filename = "student_scores.csv"
output_filename = "chosen_students.csv"

with open(input_filename, "r") as file, open(output_filename, "w") as output_file:
    output_file.write("Student\n") 
    
    next(file)  
    
    for line in file:
        name, score = line.strip().rsplit(",", 1)  
        score = float(score) 
        
        if score >= 6.0: 
            output_file.write(f"{name}\n")

# %% [markdown]
# Check the `chosen_students.csv` file you just create, how many students are chosen? Print out the number.

# %%
### INSERT YOUR CODE HERE
chosen_filename = "chosen_students.csv"

with open(chosen_filename, "r") as file:
    lines = file.readlines()  

num_students = len(lines) - 1  

print(f" Number of chosen students: {num_students}")
# Out:
#  Number of chosen students: 159

# %% [markdown]
# ### **Question 3 - Looking for Outliers (15 points)**
# Consider ways that this algorithm might systematically miss certain kinds of edge cases. For example, what if a student has a 0 for demonstrated interest because they don’t use social media or have access to a home computer? What if a student has a very high GPA but their SAT score is low enough to bring their score down; could this mean that they had a single bad test taking day?
#
# ### Task 1
# Write a function `is_outlier()` that can check for certain kinds of outliers. It should check that:
# 1. if the demonstrated interest score is 0 or
# 2. if the normalized GPA that is more than 2 points higher than the normalized SAT score.
#
# If either of these conditions is true, it should return `True` (because this student is an outlier); otherwise, the function returns `False`.

# %%
### INSERT YOUR CODE HERE
def is_outlier(student_info):

    sat = student_info[0] / 160  
    gpa = student_info[1] * 2  
    interest = student_info[2]  

    if interest == 0 or (gpa - sat > 2):
        return True
    return False

# %% [markdown]
# ### Task 2
# Call `is_outlier()` for each student and write the students' names to a file called `outliers.csv`, one name per line if they are an outlier.

# %%
### INSERT YOUR CODE HERE
output_filename = "outliers.csv"

with open(output_filename, "w") as outlier_file:
    outlier_file.write("Student\n") 

    for i in range(len(student_names)):
        student_name = student_names[i]
        if is_outlier(primary_info[i]): 
            outlier_file.write(f"{student_name}\n")

# %% [markdown]
# Check the `outliers.csv` file you just create, how many students are identified as outliers? Print out the number.

# %%
### INSERT YOUR CODE HERE
with open("outliers.csv", "r") as file:
    lines = file.readlines()

num_outliers = len(lines) - 1  
print(f" Number of outlier students: {num_outliers}")
# Out:
#  Number of outlier students: 37

# %% [markdown]
# ### Task 3
# Combine the work that you've done now to create an improved list of students to admit to your school. Write students' names, one per line, to the file `chosen_improved.csv` if they either have a score of 6 or greater OR if they are an outlier and their score is 5 or greater. Make sure to take advantage of the work that you’ve already done by calling your functions from previous problems to help you out!

# %%
### INSERT YOUR CODE HERE
output_filename = "chosen_improved.csv"

with open(output_filename, "w") as improved_file:
    improved_file.write("Student\n")

    for i in range(len(student_names)):
        student_name = student_names[i]
        student_score = calculate_score(primary_info[i])
        
        if student_score >= 6.0 or (is_outlier(primary_info[i]) and student_score >= 5.0):
            improved_file.write(f"{student_name}\n")

# %% [markdown]
# Check the `chosen_improved.csv` file you just create, how many students are chosen by this improved algorithm? Print out the number.

# %%
### INSERT YOUR CODE HERE
with open("chosen_improved.csv", "r") as file:
    lines = file.readlines()

num_selected = len(lines) - 1 
print(f" Number of students selected in improved list: {num_selected}")
# Out:
#  Number of students selected in improved list: 171

# %% [markdown]
# ### **Question 4 - Slightly Improved Algorithm (10 points)**
# ### Task 1
#
# Create a `calculate_score_improved()` function that calculates a student score, checks if it is an outlier, and returns `True` if the student has a score of 6 or higher OR was flagged as an outlier; otherwise, return `False`. Make sure to take advantage of the work that you've already done by calling your functions from previous problems to help you out!

# %%
### INSERT YOUR CODE HERE
def calculate_score_improved(primary_info):
    
    score = calculate_score(primary_info)

    outlier_status = is_outlier(primary_info) 

    return score >= 6 or outlier_status

# %% [markdown]
# ### Task 2
#
# Call `calculate_score_improved()` and output each student’s information (name, SAT, GPA, interest score, and high school quality) to a new file called `better_improved.csv` if `calculate_score_improved()` returned `True` for them.

# %%
### INSERT YOUR CODE HERE
output_filename = "better_improved.csv"

with open(output_filename, "w") as file:
    file.write("Student,SAT,GPA,Interest,High School Quality\n")

    for i in range(len(student_names)):
        student_name = student_names[i]  
        student_primary = primary_info[i]  

        if calculate_score_improved(student_primary):
            file.write(f"{student_name},{student_primary[0]},{student_primary[1]},{student_primary[2]},{student_primary[3]}\n")

# %% [markdown]
# Check the `better_improved.csv` file you just create, how many students are chosen by this new algorithm? Print out the number.

# %%
### INSERT YOUR CODE HERE
with open("better_improved.csv", "r") as file:
    lines = file.readlines()

num_selected_students = len(lines) - 1 

print(f" Total students selected by the improved algorithm: {num_selected_students}")
# Out:
#  Total students selected by the improved algorithm: 174

# %% [markdown]
# ### **Question 5 - GPA Checker (15 points)**
#
# A single GPA score is not a full picture of a student’s academic performance, as it may have improved over time or included outlier courses or semesters. A more context-sensitive algorithm could consider a student’s entire transcript and checks for, for example, a single class score that is more than two letter grades (20 points) lower than all other scores. For this task, you will use the second half of the data for each student in the provided file.
#
# ### Task 1
# Write a function `grade_outlier()` that takes in a list of grades (of any length) and returns `True` if one single number is more than 20 points lower than all other numbers; otherwise, `False`.
#
# Example:
#
# > Input: [99, 94, 87, 89, 56, 78, 89]
#
# Hint: Sort the list from lowest to highest, and check for the difference between the two lowest grades.
#
# 78 - 56 = 22; 22 > 20
#
# > Output: True
#
# Next, consider the data that we have: a list of grades for each student, one grade per semester for four semesters.
#
# Make sure that your `grade_outlier()` function works by calling it for every row in the second dataset. Print out an informative message about which students have a single grade outlier. You'll delete this later but it's a great way of testing your function!
#
# Finally, consider the importance of an algorithm being able to flag students who might have a lower overall GPA but have shown improvement over time.

# %%
### INSERT YOUR CODE HERE
def grade_outlier(grades):
    grades = sorted(grades)  
    
    if len(grades) < 2: 
        return False
    
    if grades[1] - grades[0] > 20:  
        return True 
    
    return False

# %% [markdown]
# ### Task 2
# Create a function `grade_improvement()` that returns `True` if the average score of each semester is higher than or equal to each previous semester and `False` otherwise.
#
# Hint: investigate how the `==` operator works between two lists and think about using the Python's `sorted()` function.

# %%
### INSERT YOUR CODE HERE

def grade_improvement(grades):
    return grades == sorted(grades)

# %% [markdown]
# ### Task 3
#
# Using the grade information that you've just learned, create conditions based on the information from the previous problems and `grade_outlier()` and `grade_improvement()` to choose all students if they either have a score of 6 or greater or if they have a score of 5 or more and at least one of the following is true:
#
# - `is_outlier()` returns `True`
# - `grade_outlier()` returns `True`
# - or `grade_improvement()` returns `True`
#
# Write the students who fit this description to `composite_chosen.csv`, one name per line.

# %%
### INSERT YOUR CODE HERE
output_filename = "composite_chosen.csv"

with open(output_filename, "w") as file:
    file.write("Student\n") 

    for i in range(len(student_names)):
        student_name = student_names[i] 
        student_score = student_scores[i] 
        student_grades = semester_grades[i]
        student_primary = primary_info[i] 

        if (student_score >= 6) or \
           (student_score >= 5 and (is_outlier(student_primary) or grade_outlier(student_grades) or grade_improvement(student_grades))):

            file.write(f"{student_name}\n")

# %% [markdown]
# Check the `composite_chosen.csv` file you just create, how many students are chosen by this algorithm? Print out the number.

# %%
### INSERT YOUR CODE HERE
with open("composite_chosen.csv", "r") as file:
    lines = file.readlines()

num_selected_students = len(lines) - 1  

print(f" Total students selected in composite_chosen.csv: {num_selected_students}")
# Out:
#  Total students selected in composite_chosen.csv: 174

# %% [markdown]
# **Note**:
#
# We will be testing your program using a file with the same format but different data! Make sure that you haven't "hard coded" anything specific to your data.

# %% [markdown]
# ## **PART 2 REFLECTION TASKS**
#
# Based on the algorithm you just implemented, answer the following questions:
#
# ### **Question 6 - Reflect on the outcomes (15 points)**
#
# In 100 to 200 words, reflect on the outcomes of your implemented algorithms. What are some examples of ways these algorithms might still give undesirable results for certain types of prospective students?

# %% [markdown]
# Type your answer here:

# %% [markdown]
# - There are some issues with setting outliers.
#
# 1. For example, interest equals to 0 cannot be absolute outlier. Not all of them don't use social media or have access to a home computer. It may also be due to their procrastination or lack of information gathering ability. Even without a computer and social media, they can still show their interests through sending letters, participating in offline activities organized by the school, making phone calls, and others to show their interests
#
# 2. In my opinion, when the grades are abnormally low in a certain semester, it is also important to calculate the grades of the other three semesters. If one grade is extremely low, influencing the other three high grades(like 10, 90, 90, 90), then leads to not meet the requirements, it will miss some capable people. At the same time, a abnormal grade in a certain semester cannot be completely classified as an outlier. If due to family reasons such as father’s death, or getting seriously ill can indeed be considered as an outlier. but if is due to stress, that grade can't be regarded as outlier. Since self-regulation ability in the face of pressure is also important ability

# %% [markdown]
# ### **Question 7 - How should and shouldn’t algorithms be used in college admissions? Why? (15 points)**
#
# Given the realities of time and resources (i.e., only limited person-hours can be involved in the admission process), do you think we should use algorithms like these for the admission process (assuming the real-world algorithm is far more sophisticated than the one you just created)? Explain your thinking, taking into account possible undesirable outcomes.

# %% [markdown]
# Type your answer here:

# %% [markdown]
# - During the admission process, universities need to process a large amount of data received. If these data are processed and filtered by human to determine which students meet the requirements, it is very easy to make mistakes and biases and will consume a lot of time and resources.
#
#     The use of algorithms can efficiently process a large number of applications, quickly select the applicants who do not meet the requirements, reducing human errors and biases, and improve accuracy. For example, students with GPA higher than a certain value can be quickly selected, while students with low overall levels can be quickly excluded. At the same time, it will not consume huge human resources.
#
#     But no matter how advanced the algorithm is, it is always based on existing data to have training and then make decisions. If there are problems with the training data, the algorithm will be biased, which will affect the fairness.
#     At the same time, for those students with low-come and less resources, they may be at a disadvantage in exam, extracurricular activities and so on. Even if they have strong learning potential, algorithms may not prioritize recommending them, but instead choose students from affluent families because their schools have richer resources, can provide better SAT preparation guidance, and have more extracurricular activity resources
#     Algorithms can deal with standardized data such as grades very easy, but it is not so good when handle personal experiences, extracurricular activities, social responsibility, and other such data, which may lead to misjudging the abilities of certain students
#
#     In summary, my suggestion is to adopt an algorithm+manual review model. Algorithms have great advantages in handling standardized data (SAT, GPA, grade), while manual review can compensate for the shortcomings of algorithms in handling student background, personal experience, social responsibility, and other data.
#
#     So I think algorithms need to be used, in order to improve efficiency and accuracy. But at the same time, manual review must also be employed, further improve accuracy, and compensate for the disadvantages of the algorithm I mentioned earlier.
